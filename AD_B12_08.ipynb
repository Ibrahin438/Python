# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1,2,4]
y = [1,4,9]

# %%
plt.plot(x,y)
plt.show()

# %%
Req: Create a sales Graph
    Where in your x-axis as sales
    and then your y-axis as revenue

# %%
x = [1,8,9]
y = [1,5,7]

# %%
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.show()

# %%
#Req Give the name to the graph:
      name as "sales performance"

# %%
plt.title("sales performance")
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.show()

# %%
# Adding one more data 'Z'

# %%
z = [10,5,0]

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
To know which line is X,y,Z using one more method "legend"

# %%
plt.title("sales performance")
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.plot(x,z)
plt.legend(['this is x and y' , 'this is x and z'])
plt.show()
