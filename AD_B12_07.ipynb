# %%
import numpy as np

import pandas as pd

# %%
Datasets:  
           purchase.csv
           purchase.json

# %%
Now IMDB datasets

# %%
dataset: IMDB dataset to be used

# %%
#How to read IMDB dataset file

# %%
movies_df = pd.read_csv('IMDB-Movie-Data.csv')

movies_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#req: I want to see only top rows of above o/p

# %%
movies_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#In thr above command we use  number

# %%
movies_df.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
movies_df.head(550)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 545   546         Midnight Special      Drama,Mystery,Sci-Fi
# 546   547        Don't Think Twice              Comedy,Drama
# 547   548      Alice in Wonderland  Adventure,Family,Fantasy
# 548   549                    Chuck     Biography,Drama,Sport
# 549   550          I, Daniel Blake                     Drama
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#req: I want to see the last  rows of above data sets

# %%
movies_df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
movies_df.tail(2)
# Out:
#      Rank         Title                  Genre  \
# 998   999  Search Party       Adventure,Comedy
# 999  1000    Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 998                 93     5.6   4881                 NaN       22.0
# 999                 87     5.3  12435               19.64       11.0

# %%
movies_df.tail(840)
# Out:
#      Rank                        Title                      Genre  \
# 160   161                         Mine               Thriller,War
# 161   162                    Free Fire        Action,Comedy,Crime
# 162   163   X-Men: Days of Future Past    Action,Adventure,Sci-Fi
# 163   164  Jack Reacher: Never Go Back     Action,Adventure,Crime
# 164   165                Casino Royale  Action,Adventure,Thriller
# ..    ...                          ...                        ...
# 995   996         Secret in Their Eyes        Crime,Drama,Mystery
# 996   997              Hostel: Part II                     Horror
# 997   998       Step Up 2: The Streets        Drama,Music,Romance
# 998   999                 Search Party           Adventure,Comedy
# 999  1000                   Nine Lives      Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 160  After a failed assassination attempt, a soldie...   Fabio Guaglione
# ...

# %%
#req: I want to know information about our data
       using the method .info()

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#for shot info

# %%
movies_df.shape
# Out:
# (1000, 12)

# %%
#** Handling duplicates:

# %%
temp_df = movies_df.append(movies_df)

temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                2000 non-null   int64
#  1   Title               2000 non-null   object
#  2   Genre               2000 non-null   object
#  3   Description         2000 non-null   object
#  4   Director            2000 non-null   object
#  5   Actors              2000 non-null   object
#  6   Year                2000 non-null   int64
#  7   Runtime (Minutes)   2000 non-null   int64
#  8   Rating              2000 non-null   float64
#  9   Votes               2000 non-null   int64
#  10  Revenue (Millions)  1744 non-null   float64
#  11  Metascore           1872 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 203.1+ KB

# %%
temp_df = movies_df.append(movies_df)

temp_df.shape
# Out:
# (2000, 12)

# %%
# tocheck the data of duplicate

# %%
temp_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#req: Column based duplicates handling

# %%
temp_df = movies_df.append(movies_df)

temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                2000 non-null   int64
#  1   Title               2000 non-null   object
#  2   Genre               2000 non-null   object
#  3   Description         2000 non-null   object
#  4   Director            2000 non-null   object
#  5   Actors              2000 non-null   object
#  6   Year                2000 non-null   int64
#  7   Runtime (Minutes)   2000 non-null   int64
#  8   Rating              2000 non-null   float64
#  9   Votes               2000 non-null   int64
#  10  Revenue (Millions)  1744 non-null   float64
#  11  Metascore           1872 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 203.1+ KB

# %%
temp_df = temp_df.drop_duplicates(4)

temp_df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e8754d4ee150> in <module>
# ----> 1 temp_df = temp_df.drop_duplicates(4)
#       2
#       3 temp_df.shape
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Int64Index([4], dtype='int64')

# %%
temp_df = movies_df.drop_duplicates(4)

temp_df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1c949396b13f> in <module>
# ----> 1 temp_df = movies_df.drop_duplicates(4)
#       2
#       3 temp_df.shape
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Int64Index([4], dtype='int64')

# %%
#method to be used for oringnal data 
  drop_duplicate()

# %%
temp_df = temp_df.drop_duplicates()

temp_df.shape
# Out:
# (1000, 12)

# %%
#req: column names to be displayed

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
temp_df = temp_df.drop_duplicates()

temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 101.6+ KB
