# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# creation of a piechart by using a matplotlib

# %%
# data to plot

labels = 'python','c++','Ruby','Java'
sizes = [275,120,250,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
explode = (0.1,0,0,0)

# %%
# plotting the pie chart
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=140)

plt.axis('equal')
plt.show()

# %%
labels = 'python','c++','Ruby','Java'
sizes = [ 185, 110,225,290]
colors = ['blue','red','black','brown']
explode = (0.2,0,0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.2f%%',shadow=True,startangle=150)

plt.axis('equal')
plt.show()

# %%
labels = 'python','c++','Ruby','Java'
sizes = [ 231, 101,252,150]
colors = ['gray','pink','purple','indigo']
explode = (0.2,0.1,0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.4f%%',shadow=True,startangle=160)

plt.axis('equal')
plt.show()

# %%
labels = 'python','c++','Ruby','Java'
sizes = [ 322, 401,352,250]
colors = ['red','brown','yellow','green']
explode = (0.2,0.1,0.3,0.4)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.8f%%',shadow=True,startangle=700)

plt.axis('equal')
plt.show()
